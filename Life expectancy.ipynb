# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(rc={'figure.figsize':(30,10)})
# %matplotlib inline

# %%
#read in dataset
df = pd.read_excel('lifeexpect.xls')

# %%
#check the head of the dataset
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
# 3             69     0.01               78.184215         67.0      2787  ...
# 4             71     0.01                7.097109         68.0      3013  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
#check the columns
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
#check the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
# Country                            2938 non-null object
# Year                               2938 non-null int64
# Status                             2938 non-null object
# Life expectancy                    2928 non-null float64
# Adult Mortality                    2928 non-null float64
# infant deaths                      2938 non-null int64
# Alcohol                            2744 non-null float64
# percentage expenditure             2938 non-null float64
# Hepatitis B                        2385 non-null float64
# Measles                            2938 non-null int64
#  BMI                               2904 non-null float64
# under-five deaths                  2938 non-null int64
# Polio                              2919 non-null float64
# Total expenditure                  2712 non-null float64
# Diphtheria                         2919 non-null float64
# ...

# %%
#descriptive statistics
df.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
#check there are no duplicates in the dataset.  
print('Number of duplicates:', df.duplicated().sum())
df.isnull().sum()
# Out:
# Number of duplicates: 0
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# sns.pairplot(df)

# %%
# distribution plot of life expectancies highest around the 77 point.
sns.distplot(df['Life expectancy '],kde=False, bins=30)
# Out:
# C:\Users\marcu\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\marcu\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
#linear relationship between gdp and life expectancy
sns.jointplot(x='GDP',y='Life expectancy ',data=df,kind='reg')

# %%
#slight increase in age pple are living to 
sns.jointplot(x='Year',y='Life expectancy ',data=df,kind='scatter')

# %%
#correlation of the database
df.corr()
# Out:
#                                      Year  Life expectancy   Adult Mortality  \
# Year                             1.000000          0.170033        -0.079052
# Life expectancy                  0.170033          1.000000        -0.696359
# Adult Mortality                 -0.079052         -0.696359         1.000000
# infant deaths                   -0.037415         -0.196557         0.078756
# Alcohol                         -0.052990          0.404877        -0.195848
# percentage expenditure           0.031400          0.381864        -0.242860
# Hepatitis B                      0.104333          0.256762        -0.162476
# Measles                         -0.082493         -0.157586         0.031176
#  BMI                             0.108974          0.567694        -0.387017
# under-five deaths               -0.042937         -0.222529         0.094146
# Polio                            0.094158          0.465556        -0.274823
# ...

# %%
#heatmap of different factors against each other
sns.heatmap(df.corr(),cmap='inferno')

# %%
sns.scatterplot(x=' BMI ',y='Life expectancy ',data=df)

# %%
sns.lmplot(x=' BMI ',y='Life expectancy ',data=df)

# %%
#Swarmplot - developed countries tend to live to a good age.  There is a spread in the developing countries.
sns.swarmplot(x='Status',y='Life expectancy ',data=df)
# Out:
# C:\Users\marcu\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\marcu\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.violinplot(x='Status',y='Total expenditure',data=df)

# %%
sns.violinplot(x='Status',y='infant deaths',data=df)

# %%
#check the columns
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
sns.barplot(x='Status',y='Hepatitis B',data=df)

# %%
sns.violinplot(x='Status',y='Measles ',data=df)

# %%
sns.barplot(x='Status',y='under-five deaths ',data=df)

# %%
sns.barplot(x='Status',y='Polio',data=df)

# %%
sns.barplot(x='Status',y='Diphtheria ',data=df)

# %%
sns.barplot(x='Status',y='Alcohol',data=df)

# %%
sns.barplot(x='Status',y=' HIV/AIDS',data=df)

# %%
sns.barplot(x='Status',y='Schooling',data=df)

# %%
sns.boxplot(x="Year", y="Schooling", hue="Status",data=df, palette="coolwarm")

# %%
sns.lmplot(x="Year", y=" BMI ", hue="Status",data=df, palette="coolwarm")

# %%
sns.lmplot(x="Year", y="Alcohol", hue="Status",data=df, palette="coolwarm")

# %%
sns.barplot(x="Year", y="GDP", hue="Status",data=df, palette="coolwarm")

# %%
sns.boxplot(x="Year", y="Total expenditure", hue="Status",data=df, palette="coolwarm")

# %%
sns.boxplot(x="Year", y="Alcohol", hue="Status",data=df, palette="coolwarm")

# %%
country = df.groupby('Country')

# %%
country.first()
# Out:
#                                     Year      Status  Life expectancy   \
# Country
# Afghanistan                         2015  Developing              65.0
# Albania                             2015  Developing              77.8
# Algeria                             2015  Developing              75.6
# Angola                              2015  Developing              52.4
# Antigua and Barbuda                 2015  Developing              76.4
# ...                                  ...         ...               ...
# Venezuela (Bolivarian Republic of)  2015  Developing              74.1
# Viet Nam                            2015  Developing              76.0
# Yemen                               2015  Developing              65.7
# Zambia                              2015  Developing              61.8
# Zimbabwe                            2015  Developing              67.0
#
#                                     Adult Mortality  infant deaths  Alcohol  \
# Country
# ...

# %%
sns.swarmplot(x="Year", y="Life expectancy ", data=df,hue='Status',split=True,palette='Set1')
# Out:
# C:\Users\marcu\Anaconda3\lib\site-packages\seaborn\categorical.py:2974: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)
# C:\Users\marcu\Anaconda3\lib\site-packages\seaborn\categorical.py:1324: RuntimeWarning: invalid value encountered in less
#   off_low = points < low_gutter
# C:\Users\marcu\Anaconda3\lib\site-packages\seaborn\categorical.py:1328: RuntimeWarning: invalid value encountered in greater
#   off_high = points > high_gutter

# %%
sns.swarmplot(x="Year", y="Adult Mortality", data=df,hue='Status',split=True,palette='Set1')

# %% [markdown]
# # Data science project calculating life expectancy

# %%
#import models and scoring and encoders to format variables.
# Prediction
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# Classifiers

from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# Data encoding from string to dummy
from sklearn.preprocessing import LabelEncoder

# %%
#check columns
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
#encode the string variables
lb = LabelEncoder()
df['Country'] = lb.fit_transform(df['Country'])
df['Status'] = lb.fit_transform(df['Status'])

# %%
#make a new column called LE to see who lives over 50 and who doesnt
df['LE'] = df['Life expectancy '].apply(lambda x: 0 if x < 60 else 1)

# %%
#fill empty 
y = df['Life expectancy '].fillna(0)

# %%
#features we will use to see how they affect life expectancy
features = ['Country','Status','Alcohol','Hepatitis B','Diphtheria ',' HIV/AIDS',
           'Schooling','Polio',' BMI ']

# %%
#fill na
X=df[features].fillna(0)

# %%
#split the dataset 70:30
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print('Coefficients :n', lm.coef_)
# Out:
# Coefficients :n [ 0.00696672 -4.48800165  0.23925893  0.01093099  0.03415143 -0.7263133
#   0.69049457  0.03945871  0.07411358]

# %%
lrpredictions = lm.predict(X_test)

# %%
plt.scatter(y_test,lrpredictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
# calculate these metrics by hand!
from sklearn import metrics
from sklearn.metrics import accuracy_score
import numpy as np

print('MAE:', metrics.mean_absolute_error(y_test, lrpredictions))
print('MSE:', metrics.mean_squared_error(y_test, lrpredictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, lrpredictions)))
# Out:
# MAE: 68.5272124030427
# MSE: 4750.60630334631
# RMSE: 68.92464220687917

# %%
sns.distplot((y_test-lrpredictions),bins=50)

# %%
coeffecients = pd.DataFrame(lm.coef_,X.columns)
coeffecients.columns = ['Coeffecient']
coeffecients
# Out:
#              Coeffecient
# Country         0.006967
# Status         -4.488002
# Alcohol         0.239259
# Hepatitis B     0.010931
# Diphtheria      0.034151
#  HIV/AIDS      -0.726313
# Schooling       0.690495
# Polio           0.039459
#  BMI            0.074114

# %% [markdown]
# # Logistic Regression

# %%
X = df[features].fillna(0)
y = df['LE'].fillna(0)

# %%
X = X.astype(int)
y = y.astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train,y_train)
# Out:
# C:\Users\marcu\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
logpredictions = logmodel.predict(X_test)

# %%
print(classification_report(y_test,logpredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.79      0.85       175
#            1       0.95      0.98      0.97       707
#
#     accuracy                           0.94       882
#    macro avg       0.93      0.89      0.91       882
# weighted avg       0.94      0.94      0.94       882

# %%
print('Logistic Regression Result:',accuracy_score(y_test,logpredictions))
# Out:
# Logistic Regression Result: 0.9444444444444444

# %% [markdown]
# # Decision Tree Classifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dpredictions = dtree.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
print('Decision Tree Result:',accuracy_score(y_test,dpredictions))
# Out:
# Decision Tree Result: 0.9671201814058957

# %%
print(confusion_matrix(y_test,dpredictions))
# Out:
# [[159  16]
#  [ 13 694]]

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=600)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=600,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
rfcpredictions = rfc.predict(X_test)

# %%
print(classification_report(y_test,rfcpredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       175
#            1       0.99      0.99      0.99       707
#
#     accuracy                           0.98       882
#    macro avg       0.98      0.97      0.97       882
# weighted avg       0.98      0.98      0.98       882

# %%
print('Random forest classifier result:',accuracy_score(y_test,rfcpredictions))
# Out:
# Random forest classifier result: 0.981859410430839

# %%
feature_importances = pd.Series(rfc.feature_importances_,X.columns[::])
print(feature_importances)
# Out:
# Country        0.063533
# Status         0.001383
# Alcohol        0.028247
# Hepatitis B    0.039781
# Diphtheria     0.071932
#  HIV/AIDS      0.423394
# Schooling      0.135138
# Polio          0.083466
#  BMI           0.153126
# dtype: float64

# %%
newfi = feature_importances.sort_values(ascending=False)

# %%
#These are the most important factors that determine who lives over 60 and who doesnt.
newfi
# Out:
#  HIV/AIDS      0.423394
#  BMI           0.153126
# Schooling      0.135138
# Polio          0.083466
# Diphtheria     0.071932
# Country        0.063533
# Hepatitis B    0.039781
# Alcohol        0.028247
# Status         0.001383
# dtype: float64

# %% [markdown]
# # Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(X_train,y_train)
# Out:
# C:\Users\marcu\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svcpredictions = model.predict(X_test)

# %%
print(classification_report(y_test,svcpredictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.17      0.28       175
#            1       0.83      1.00      0.91       707
#
#     accuracy                           0.83       882
#    macro avg       0.91      0.58      0.60       882
# weighted avg       0.86      0.83      0.78       882

# %%
print(confusion_matrix(y_test,svcpredictions))
# Out:
# [[ 29 146]
#  [  0 707]]

# %%
print('Support Vector Classifier:',accuracy_score(y_test,svcpredictions))
# Out:
# Support Vector Classifier: 0.8344671201814059

# %% [markdown]
# # Conclusion

# %% [markdown]
# # The methods we have used:
# Using the continuous variable of Life expectancy
# Linear Regression
# Calculated the linear coefficients
#
# Support Vector Classifier =  0.83
# Decision Tree Classifier = 0.96
# Random Forest Classifier = 0.98
#
# Calculated the most important features using Random Forest:
# HIV
# BMI
# Schooling
# Polio
# Diptheria
# to decide if you will live over 60 or less than 60
